# %% [markdown]
# This is the code used for SVM and NaiveBayes algorithms.
# Specifically, this is the version for analyzing monograms.
# To analyze bigrams it's enough to change this:
#
# Tfidf_vect = TfidfVectorizer(max_features=5000, ngram_range=(1,1)) ----> Tfidf_vect = TfidfVectorizer(max_features=5000, ngram_range=(2,2))

# %% [markdown]
# Set the dataframe: save the file .pkl on google drive and import it with the following code.

# %%
# Install the PyDrive wrapper & import libraries.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
listed = drive.ListFile({'q': "title contains '.pkl' and 'root' in parents"}).GetList()
for file in listed:
    print('title {}, id {}'.format(file['title'], file['id']))
# Out:
# title data_75_fasttext.pkl, id 1i4vviPsX50thW6KTg_x8p41BlmvAkng5
# title refined_giacomo_100.pkl, id 107988YA16LXnv_b1cTkyf8-wqFlVnMsB
# title refined_giacomo_75.pkl, id 1Uxbiwkwt3Wt1vH-vZfD6k36J8SMBJHrz
# title refined1.pkl, id 1_-xtFh-iPf2-prHJeNZnOuR_y0WZlPLZ
# title base_df.pkl, id 1Q1HYn8Xgp0azDuzFoSmRggg3GcWuizF3

# %%
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

import io
import pickle
from googleapiclient.http import MediaIoBaseDownload

file_id = '107988YA16LXnv_b1cTkyf8-wqFlVnMsB'

request = drive_service.files().get_media(fileId=file_id)
downloaded = io.BytesIO()
downloader = MediaIoBaseDownload(downloaded, request)
done = False
while done is False:
    # _ is a placeholder for a progress object that we ignore.
    # (Our file is small, so we skip reporting progress.)
    _, done = downloader.next_chunk()

downloaded.seek(0)
f = pickle.load(downloaded)
df = f

# %%
import re
df["tweets"]=df["tweets"].apply(lambda s: ' '.join(re.sub("rt", "", s).split()))
df["tweets"]=df["tweets"].apply(lambda s: ' '.join(re.sub("pi", "", s).split()))

# %%
df.index=range(2200)

# %% [markdown]
# Add the Required Libraries.

# %%
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Set random seed: this is used to reproduce the same result every time if the script is kept consistent otherwise each run will produce different results. The seed can be set to any number.

# %%
np.random.seed(500)

# %%
# further preprocessing: tokenization and lemmatization
import nltk
nltk.download('punkt')
# Tokenization : In this each entry in the corpus will be broken into set of words
df['tweets']= [word_tokenize(entry) for entry in df['tweets']]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Let's see what we obtain when we tokenize
df['tweets']

# %%
nltk.download('wordnet')
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

# %%
nltk.download('averaged_perceptron_tagger')
for index,entry in enumerate(df['tweets']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
        Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    df.loc[index,'text_final'] = str(Final_words)

# %% [markdown]
# Prepare Train and Test Data sets: Let's split (80%-20%) the dataframe into a training set and a test set. The Corpus will be split into two data sets, Training and Test. The training data set will be used to fit the model and the predictions will be performed on the test data set.This can be done through the train_test_split from the sklearn library. The Training Data will have 80% of the corpus and Test data will have the remaining 20% as we have set the parameter test_size=0.2 .

# %%
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(df['text_final'],df['__label__'],test_size=0.2)

# %% [markdown]
# Encoding: label encode the target variable — This is done to transform Categorical data of string type in the data set into numerical values which the model can understand.

# %%
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %% [markdown]
# Word Vectorization: we will use the TF-IDF method. TF-IDF are word frequency scores that try to highlight words that are more interesting, e.g. frequent in a document but not across documents.
# The following syntax can be used to first fit the TG-IDF model on the whole corpus. This will help TF-IDF build a vocabulary of words which it has learned from the corpus data and it will assign a unique integer number to each of these words. Their will be maximum of 5000 unique words/features as we have set parameter max_features=5000. ngram_range will be set (1,1) if we want to analyze monograms, (2,2) if we want to analyze bi-grams.
# Finally we will transform Train_X and Test_X to vectorized Train_X_Tfidf and Test_X_Tfidf. These will now contain for each row a list of unique integer number and its associated importance as calculated by TF-IDF.

# %%
Tfidf_vect = TfidfVectorizer(max_features=5000, ngram_range=(1,1))
Tfidf_vect.fit(df['text_final'])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
# Let's look at the vocabulary
Tfidf_vect.vocabulary_
# Out:
# {'permesso premio': 2751,
#  'ministero dellinterno': 2246,
#  'presidente inps': 2932,
#  'valore aggiunto': 3985,
#  'classe dirigente': 779,
#  'ennesima dimostrazione': 1261,
#  'problema italiani': 2974,
#  'italiani credono': 1842,
#  'vuoi vedere': 4204,
#  'london bridge': 2024,
#  'pagina facebook': 2490,
#  'prime pagine': 2964,
#  'pagine giornali': 2493,
#  'signore signori': 3598,
#  'reddito cittadinanza': 3132,
#  'tanti giovani': 3824,
#  'giustizia bonafede': 1594,
#  'maio salvini': 2082,
#  'mld euro': 2256,
#  'roba matti': 3260,
#  'punto vista': 3059,
#  'pagare tasse': 2485,
#  'conti correnti': 903,
#  'sar sicuramente': 3439,
#  'matteo renzi': 2145,
#  'presto sar': 2956,
#  'programma elettorale': 3001,
#  'ambasciatore cinese': 96,
#  'parlamento italiano': 2556,
#  'cambium idea': 548,
#  'debito pubblico': 1020,
#  'luned mattina': 2047,
#  'solita storia': 3679,
#  'conto corrente': 915,
#  'andr finire': 148,
#  'fondo salva': 1470,
#  'moi feriti': 2263,
#  'angela merkel': 151,
#  'commissione bilancio': 836,
#  'prendere giro': 2910,
#  'movimento spontaneo': 2282,
#  'elezioni regionali': 1244,
#  'parlamentari italiani': 2550,
#  'sinistra destra': 3621,
#  'hong kong': 1680,
#  'lotta evasione': 2028,
#  'grandi evasori': 1634,
#  'azza manifestare': 302,
#  'dovere morale': 1201,
#  'stasera sar': 3738,
#  'genere umano': 1525,
#  'sar mica': 3432,
#  'intendere volere': 1745,
#  'immunit parlamentare': 1706,
#  'buongiorno buon': 498,
#  'buon venerd': 468,
#  'avvocato popolo': 292,
#  'fate girare': 1377,
#  'decine migliaia': 1023,
#  'prendono soldi': 2917,
#  'firmiamo cazzo': 1448,
#  'claudio scusi': 788,
#  'banche italiane': 337,
#  'dovrebbe chiedere': 1206,
#  'perch italiani': 2673,
#  'giallo verde': 1540,
#  'salvini cadere': 3339,
#  'manifestazione azza': 2098,
#  'forze dellordine': 1478,
#  'presidente conte': 2928,
#  'coda paglia': 797,
#  'matteo salvini': 2146,
#  'italia grecia': 1793,
#  'risparmi italiani': 3245,
#  'corea nord': 928,
#  'cagata pazzesca': 526,
#  'puntare dito': 3051,
#  'coe cassazione': 802,
#  'bandiera rossa': 340,
#  'salvare banche': 3330,
#  'banche tedesche': 338,
#  'palazzo chigi': 2515,
#  'figure merda': 1423,
#  'fake news': 1339,
#  'poteri foi': 2879,
#  'interessi italia': 1749,
#  'coglione coglione': 810,
#  'scritto libro': 3493,
#  'estrema sinistra': 1285,
#  'reso conto': 3188,
#  'crollano ponti': 975,
#  'accordo malta': 18,
#  'querela salvini': 3083,
#  'sardine azza': 3444,
#  'chiaro perch': 710,
#  'pensiero unico': 2628,
#  'storia vera': 3768,
#  'diffondere odio': 1100,
#  'andare dormire': 126,
#  'candidato pd': 569,
#  'gad lerner': 1513,
#  'girare video': 1580,
#  'popolo italiano': 2848,
#  'violenza sessuale': 4093,
#  'tribunale ministri': 3915,
#  'classe politica': 781,
#  'prime minister': 2963,
#  'consigliere regionale': 881,
#  'cose impoanti': 943,
#  'lega vuole': 1949,
#  'finanziamento pubblico': 1433,
#  'deutsche bank': 1066,
#  'italia bisogno': 1776,
#  'ruby nipote': 3299,
#  'nipote mubarak': 2335,
#  'radical chic': 3103,
#  'campagna elettorale': 558,
#  'emilia romagna': 1251,
#  'farci credere': 1361,
#  'beppe grillo': 382,
#  'salva salvini': 3327,
#  'cassa depositi': 629,
#  'depositi prestiti': 1052,
#  'movimento stelle': 2283,
#  'vediamo stasera': 4003,
#  'rotto cazzo': 3295,
#  'perch donna': 2661,
#  'claudio borghi': 782,
#  'conferenza stampa': 871,
#  'perch necessario': 2682,
#  'luigi maio': 2045,
#  'unione europea': 3965,
#  'staccare sna': 3722,
#  'ponti viadotti': 2841,
#  'ormai chiaro': 2448,
#  'traffico influenze': 3902,
#  'riferire aula': 3218,
#  'farla franca': 1363,
#  'codice penale': 799,
#  'incaricato italiano': 1717,
#  'italiano trattare': 1872,
#  'trattare estero': 3905,
#  'estero affari': 1283,
#  'salvini conte': 3345,
#  'dichiarazione voto': 1084,
#  'parlamento europeo': 2555,
#  'nuova commissione': 2378,
#  'poi apei': 2796,
#  'cari amici': 604,
#  'poo sicuro': 2842,
#  'ragione salvini': 3115,
#  'parit genere': 2541,
#  'esseri umani': 1282,
#  'centro accoglienza': 685,
#  'alan kurdi': 59,
#  'sar perch': 3434,
#  'capogruppo lega': 586,
#  'lega lega': 1934,
#  'italia viene': 1830,
#  'storia italia': 3761,
#  'renzi conte': 3164,
#  'concessioni benetton': 862,
#  'cantano bella': 578,
#  'bella ciao': 356,
#  'salvare vite': 3333,
#  'regione emonte': 3142,
#  'violenza fisica': 4091,
#  'decreto fiscale': 1030,
#  'claudio scusa': 787,
#  'coe appello': 801,
#  'pensa diversamente': 2625,
#  'ieri clipno': 1691,
#  'sovranit appaiene': 3691,
#  'appaiene popolo': 179,
#  'banca centrale': 332,
#  'bambino moi': 330,
#  'chiedere aiuto': 720,
#  'dissesto idrogeologico': 1144,
#  'danni fatti': 994,
#  'moneta unica': 2268,
#  'guardia costiera': 1663,
#  'politica estera': 2804,
#  'senatrice segre': 3542,
#  'posso credere': 2862,
#  'problema immigrazione': 2972,
#  'mila euro': 2225,
#  'venire italia': 4020,
#  'fabio fazio': 1326,
#  'giorgia meloni': 1555,
#  'semplice perch': 3531,
#  'povera italia': 2885,
#  'politicamente corretto': 2816,
#  'tanti italiani': 3825,
#  'navi ong': 2297,
#  'maggioranza italiani': 2067,
#  'italiani salvini': 1859,
#  'paolo gentiloni': 2526,
#  'difficile care': 1098,
#  'servizio pubblico': 3573,
#  'problema serio': 2980,
#  'striscia notizia': 3782,
#  'entrata vigore': 1267,
#  'conte tria': 898,
#  'renzi pd': 3171,
#  'sbarcare italia': 3450,
#  'italia francia': 1788,
#  'spese contribuenti': 3711,
#  'crolla viadotto': 974,
#  'sbarcati italia': 3452,
#  'italia migranti': 1805,
#  'grillo maio': 1648,
#  'secolo italia': 3504,
#  'vogliamo andare': 4118,
#  'lavori pubblici': 1916,
#  'italiani cato': 1840,
#  'rotazione poi': 3294,
#  'poi italiani': 2798,
#  'tanti amici': 3822,
#  'spesa pubblica': 3710,
#  'sentito parlare': 3556,
#  'concessione autostradale': 858,
#  'avvocato italiani': 291,
#  'lucia borgonzoni': 2041,
#  'sondaggio swg': 3685,
#  'cade pezzi': 521,
#  'ponti crollano': 2840,
#  'maio attacca': 2075,
#  'canta bella': 577,
#  'avanzo primario': 282,
#  'diritti lavoratori': 1124,
#  'wan na': 4224,
#  'alto tradimento': 88,
#  'ocean viking': 2405,
#  'avviso garanzia': 289,
#  'vuole tornare': 4217,
#  'utero affitto': 3980,
#  'immigrazione incontrollata': 1705,
#  'banca etruria': 333,
#  'blog stelle': 414,
#  'violenza donne': 4090,
#  'presidente repubblica': 2940,
#  'repubblica italiana': 3181,
#  'guardia finanza': 1664,
#  'solidariet popolo': 3677,
#  'dipendenti pubblici': 1104,
#  'societ civile': 3652,
#  'idea politica': 1687,
#  'elezioni emilia': 1239,
#  'domani sar': 1171,
#  'sar oste': 3433,
#  'salvini spara': 3381,
#  'opera ae': 2430,
#  'casce cazzo': 626,
#  'interessi italiani': 1750,
#  'livello europeo': 2019,
#  'forze ordine': 1479,
#  'pro immigrazione': 2968,
#  'movimento sardine': 2281,
#  'carola rackete': 616,
#  'anti italiano': 170,
#  'italia italiani': 1798,
#  'domanda perch': 1159,
#  'figlio grillo': 1420,
#  'spese italiani': 3712,
#  'dovrebbe stare': 1209,
#  'stare galera': 3733,
#  'italia immigrati': 1795,
#  'immigrati clandestini': 1701,
#  'mamma mamma': 2088,
#  'italia ue': 1826,
#  'cittadini europei': 764,
#  'monte paschi': 2270,
#  'litalia bisogno': 2015,
#  'seghi perch': 3515,
#  'fate presto': 1379,
#  'care perch': 600,
#  'preso culo': 2950,
#  'aldo moro': 66,
#  'mattia santori': 2148,
#  'leader lega': 1920,
#  'vero perch': 4046,
#  'presidente regione': 2939,
#  'regione emilia': 3141,
#  'paito unico': 2511,
#  'voglio vedere': 4128,
#  'scende azza': 3467,
#  'risposta domanda': 3252,
#  'salvini attacca': 3336,
#  'italiano perch': 1870,
#  'salvare poltrona': 3332,
#  'paolo savona': 2527,
#  'presentato emendamento': 2921,
#  'commissione europea': 838,
#  'post video': 2874,
#  'andiamo votare': 146,
#  'pezzi merda': 2770,
#  'vero problema': 4047,
#  'salvini perch': 3368,
#  'andiamo voto': 147,
#  'figli pap': 1414,
#  'politica seria': 2812,
#  'polizia postale': 2832,
#  'paito bibbiano': 2501,
#  'alleanza pd': 78,
#  'moe agenti': 2262,
#  'permesso soggiorno': 2752,
#  'decreto sicurezza': 1034,
#  'sentire parlare': 3553,
#  'toccato fondo': 3881,
#  'figli nipoti': 1413,
#  'tratta esseri': 3904,
#  'italia rischia': 1819,
#  'ristrutturazione debito': 3254,
#  'affidi illeciti': 45,
#  'reggio emilia': 3138,
#  'fondo salvastati': 1471,
#  'maio italia': 2079,
#  'colore politico': 816,
#  'destra perch': 1061,
#  'giuseppe conte': 1593,
#  'paolo becchi': 2523,
#  'concessione autostrade': 859,
#  'scudo penale': 3498,
#  'penale ilva': 2624,
#  'violato legge': 4089,
#  'buona notizia': 482,
#  'coe conti': 803,
#  'scendere azza': 3471,
#  'pochi minuti': 2791,
#  'difficile trovare': 1099,
#  'riccardo molinari': 3200,
#  'ilaria cucchi': 1694,
#  'sindaco rom': 3618,
#  'andare elezioni': 127,
#  'elezioni perch': 1242,
#  'prossimo presidente': 3030,
#  'centro rom': 689,
#  'centri sociali': 684,
#  'prende soldi': 2900,
#  'soldi pagare': 3665,
#  'pagare debiti': 2483,
#  'italia unico': 1828,
#  'buffone buffone': 446,
#  'mila posti': 2226,
#  'meccanismo europeo': 2153,
#  'europeo stabilit': 1313,
#  'guardate immagini': 1661,
#  'sangue freddo': 3409,
#  'claudio perch': 786,
#  'anti salvini': 171,
#  'rom perch': 3277,
#  'rassegna stampa': 3119,
#  'dovr pagare': 1204,
#  'salvini dato': 3349,
#  'bisogna bloccare': 396,
#  'bloccare bisogna': 407,
#  'imprese italiane': 1712,
#  'spendere soldi': 3704,
#  'fatemi care': 1384,
#  'milione euro': 2236,
#  'ius solo': 1879,
#  'cambiamento climatico': 536,
#  'presidente mattarella': 2933,
#  'mezza italia': 2195,
#  'riforma fondo': 3223,
#  'dicembre sar': 1081,
#  'rendere conto': 3155,
#  'venezia sott': 4017,
#  'sott acqua': 3689,
#  'clima odio': 791,
#  'insulti social': 1741,
#  'grave errore': 1637,
#  'italiani conte': 1841,
#  'nicola porro': 2326,
#  'accordo perch': 21,
#  'odio razziale': 2408,
#  'buongiorno dioggi': 502,
#  'ius soli': 1878,
#  'soli ius': 3675,
#  'ius culturae': 1877,
#  'politica italiana': 2808,
#  'segretario pd': 3523,
#  'libri storia': 2003,
#  'viene condannato': 4071,
#  'condannato carcere': 866,
#  'rotto coglioni': 3296,
#  'giglio magico': 1546,
#  'votano lega': 4158,
#  'perch posso': 2701,
#  'votare lega': 4160,
#  'perch sinistra': 2714,
#  'senso unico': 3547,
#  'arrivati punto': 226,
#  'procura milano': 2994,
#  'livello internazionale': 2020,
#  'tassa merendine': 3833,
#  'redistribuzione migranti': 3134,
#  'migranti salvini': 2217,
#  'barbara lezzi': 343,
#  'sentenza coe': 3549,
#  'stefano cucchi': 3747,
#  'sar vero': 3441,
#  'rompere cazzo': 3290,
#  'lara comi': 1892,
#  'azza san': 313,
#  'fondazione einaudi': 1462,
#  'pd vota': 2611,
#  'francia italia': 1493,
#  'basso costo': 346,
#  'mamma pap': 2089,
#  'servizi sociali': 3568,
#  'maria giovanna': 2123,
#  'giovanna maglie': 1574,
#  'immigrati italia': 1703,
#  'scritto lettera': 3492,
#  'perch votare': 2732,
#  'commissione inchiesta': 841,
#  'perch vengono': 2721,
#  'perch pensa': 2693,
#  'tasse auto': 3835,
#  'auto aziendali': 272,
#  'guadagna euro': 1656,
#  'buona festa': 476,
#  'commissione segre': 844,
#  'sbarchi fantasma': 3453,
#  'nord sud': 2358,
#  'levasione fiscale': 1987,
#  'legittima difesa': 1977,
#  'nuove tasse': 2395,
#  'sugar tax': 3790,
#  'plastic tax': 2776,
#  'presentazione libro': 2922,
#  'uscire euro': 3978,
#  'soldi banche': 3658,
#  'messaggi odio': 2181,
#  'parlamentari pd': 2552,
#  'danno fastidio': 997,
#  'san giovanni': 3398,
#  'senatore repubblica': 3540,
#  'centinaia migliaia': 679,
#  'migliaia italiani': 2207,
#  'campo rom': 564,
#  'odio rete': 2410,
#  'razzismo antisemitismo': 3120,
#  'garante privacy': 1518,
#  'figura merda': 1422,
#  'radio radicale': 3104,
#  'commissione odio': 842,
#  'italia viva': 1831,
#  'firme false': 1447,
#  'profilo social': 2998,
#  'senato approva': 3535,
#  'mozione segre': 2285,
#  'odio razzismo': 2409,
#  'lanno prossimo': 1891,
#  'capo politico': 582,
#  'robeo fico': 3261,
#  'lilli gruber': 2009,
#  'capo polizia': 583,
#  'eni poteri': 1260,
#  'pareggio bilancio': 2537,
#  'rom azza': 3267,
#  'tor gnattara': 3887,
#  'catale italia': 637,
#  'perch lega': 2675,
#  'lega votato': 1948,
#  'votato pd': 4173,
#  'voti pd': 4179,
#  'chiedo scusa': 728,
#  'raccolta firme': 3097,
#  'coop rosse': 921,
#  'patto stabilit': 2578,
#  'italiani dovrebbero': 1845,
#  'boris johnson': 426,
#  'conte maio': 889,
#  'settimana scorsa': 3580,
#  'gori grillo': 1616,
#  'maio zingaretti': 2085,
#  'mafia catale': 2061,
#  'permessi premio': 2750,
#  'prossime elezioni': 3027,
#  'vedremo belle': 4007,
#  'catale europea': 635,
#  'salvini zingaretti': 3392,
#  'cate perch': 643,
#  'reti unificate': 3192,
#  'alta velocit': 81,
#  'discover google': 1140,
#  'paito democratico': 2503,
#  'fissa dimora': 1450,
#  'voto anziani': 4182,
#  'lega fdi': 1927,
#  'conte sar': 897,
#  'maggioranza assoluta': 2066,
#  'togliere voto': 3883,
#  'prossimo giro': 3028,
#  'curioso vedere': 987,
#  'marco rizzo': 2116,
#  'pd stelle': 2608,
#  'pezzo merda': 2771,
#  'migranti italia': 2215,
#  'paito comunista': 2502,
#  'prende voti': 2901,
#  'imu chiesa': 1714,
#  'diego fusaro': 1091,
#  'papa bergoglio': 2530,
#  'ordine mondiale': 2442,
#  'capro esatorio': 589,
#  'conflitto interessi': 876,
#  'diritto costituzionale': 1126,
#  'punto ritorno': 3058,
#  'ciao ciao': 744,
#  'silenzio elettorale': 3601,
#  'false notizie': 1343,
#  'sciogliere camere': 3483,
#  'mya merlino': 2290,
#  'cazzaro verde': 659,
#  'perch popolo': 2699,
#  'disco rotto': 1137,
#  'terza medium': 3858,
#  'politici pd': 2823,
#  'financial time': 1428,
#  'taglio parlamentari': 3806,
#  'diretta pagina': 1110,
#  'luca sacchi': 2036,
#  'vera propria': 4027,
#  'exit poll': 1322,
#  'buona fede': 475,
#  'elezioni umbria': 1245,
#  'raggi rom': 3111,
#  'agenzia entrate': 50,
#  'unica speranza': 3958,
#  'donald trump': 1183,
#  'chiesto scusa': 732,
#  'stelle renzi': 3752,
#  'vorrei sapere': 4150,
#  'buona domenica': 474,
#  'buongiorno amici': 496,
#  'amici camerati': 100,
#  'papa francesco': 2531,
#  'vuole togliere': 4216,
#  'diritto voto': 1132,
#  'sega perch': 3510,
#  'amici umbri': 104,
#  'voto umbria': 4197,
#  'regionali umbria': 3140,
#  'legge bilancio': 1953,
#  'parla perch': 2545,
#  'hillary clinton': 1678,
#  'cazzo pare': 663,
#  'perch destra': 2654,
#  'pove assoluta': 2884,
#  'legge legge': 1961,
#  'mario draghi': 2129,
#  'sondaggi danno': 3684,
#  'voto scambio': 4194,
#  'cittadini umbri': 768,
#  'poliziotti uccisi': 2833,
#  'mandare onda': 2091,
#  'repo salvini': 3179,
#  'potere popolo': 2878,
#  'mettere discussione': 2191,
#  'chiedi scusa': 724,
#  'scusa perch': 3502,
#  'costiera libica': 957,
#  'bocca lupo': 415,
#  'regione umbria': 3146,
#  'buco nero': 444,
#  'centri commerciali': 681,
#  'buonasera amici': 493,
#  'mafia nigeriana': 2063,
#  'senatrice liliana': 3541,
#  'liliana segre': 2008,
#  'rendete conto': 3157,
#  'moneta elettronica': 2267,
#  'inchiesta repo': 1719,
#  'coe costituzionale': 804,
#  'punto paenza': 3055,
#  'cope gay': 922,
#  'guerra civile': 1667,
#  'grosso problema': 1654,
#  'sostituzione etnica': 3688,
#  'dichiarazione redditi': 1083,
#  'uomini donne': 3971,
#  'cittadini italiani': 765,
#  'italiani devono': 1843,
#  'farsi carico': 1364,
#  'buon senso': 466,
#  'puntata repo': 3052,
#  'politicamente corretta': 2815,
#  'perfettamente accordo': 2748,
#  'strada rom': 3772,
#  'risolvere problema': 3243,
#  'figli puttana': 1416,
#  'sistema bancario': 3629,
#  'tweet muto': 3930,
#  'patrimonio unesco': 2575,
#  'paesi africani': 2474,
#  'perch vogliamo': 2726,
#  'pressione fiscale': 2954,
#  'italiani pagano': 1853,
#  'pagano tasse': 2480,
#  'sinistra vuole': 3627,
#  'vittorio sgarbi': 4107,
#  'perfettamente ragione': 2749,
#  'italiani diritto': 1844,
#  'fate attenzione': 1375,
#  'cato perch': 646,
#  'perch vogliono': 2728,
#  'vogliono togliere': 4134,
#  'sbarcare migranti': 3451,
#  'chiude poi': 736,
#  'centri accoglienza': 680,
#  'soldi italiani': 3663,
#  'amministrazione comunale': 110,
#  'appena sentito': 189,
#  'grave problema': 1638,
#  'mila azza': 2222,
#  'denaro pubblico': 1051,
#  'nn credo': 2343,
#  'medium italiani': 2159,
#  'candidato civico': 568,
#  'pd leu': 2596,
#  'parlamento ue': 2557,
#  'andrea scanzi': 150,
#  'ragazzo ucciso': 3109,
#  'gon na': 1614,
#  'mezzi pubblici': 2196,
#  'enrico mentana': 1264,
#  'omicidio luca': 2421,
#  'pagina fb': 2491,
#  'appena scopeo': 187,
#  'ilva taranto': 1696,
#  'nuova sede': 2386,
#  'europa unita': 1308,
#  'sandro gozi': 3407,
#  'renzi gentiloni': 3165,
#  'patria famiglia': 2572,
#  'semina odio': 3529,
#  'intervento aula': 1756,
#  'deputato pd': 1056,
#  'sti cazzi': 3756,
#  'linea politica': 2010,
#  'insulti minacce': 1738,
#  'fatture false': 1395,
#  'richiedenti asilo': 3206,
#  'question time': 3086,
#  'salvini lega': 3357,
#  'aumento iva': 269,
#  'cda rai': 673,
#  'presunti fondi': 2957,
#  'fondi russi': 1468,
#  'russi lega': 3300,
#  'vota lega': 4154,
#  'perch italia': 2672,
#  'sigfrido ranucci': 3594,
#  'nazioni unite': 2299,
#  'italia euro': 1786,
#  'euro mese': 1294,
#  'asilo nido': 231,
#  'coe europea': 805,
#  'andate affanculo': 140,
#  'campo profughi': 563,
#  'assistenti sociali': 240,
#  'prova contraria': 3033,
#  'riposa pace': 3235,
#  'caa credito': 516,
#  'immigrazione clandestina': 1704,
#  'scappano guerra': 3460,
#  'lager libici': 1889,
#  'buon pranzo': 462,
#  'oliviero toscani': 2419,
#  'euro italia': 1292,
#  'nuove norme': 2393,
#  'giornalista repubblica': 1561,
#  'carcere grandi': 595,
#  'perch sanno': 2708,
#  'appena votato': 190,
#  'chiss perch': 735,
#  'politici italiani': 2822,
#  'servizio repo': 3574,
#  'potete vedere': 2880,
#  'sceso azza': 3474,
#  'mette mani': 2187,
#  'rom raggi': 3278,
#  'manovra economica': 2106,
#  'acerebbe sapere': 27,
#  'polizia penitenziaria': 2831,
#  'suffragio universale': 3789,
#  'libero quotidiano': 1999,
#  'commissione ue': 845,
#  'ue italia': 3937,
#  'calci pugni': 528,
#  'milano rom': 2232,
#  'perch devono': 2656,
#  'green deal': 1640,
#  'tribunale milano': 3914,
#  'francia spagna': 1495,
#  'san maino': 3400,
#  'perch ormai': 2684,
#  'vorrei vedere': 4151,
#  'fascista razzista': 1371,
#  'rom catale': 3268,
#  'libe parola': 1993,
#  'italia ultimi': 1827,
#  'roll stone': 3266,
#  'carcere evasori': 594,
#  'soliti noti': 3680,
#  'disoccupazione giovanile': 1143,
#  'aumentare tasse': 267,
#  'tasse perch': 3838,
#  'vigili fuoco': 4078,
#  'italia pd': 1811,
#  'famiglie imprese': 1350,
#  'paite iva': 2497,
#  'quaiere vasto': 3064,
#  'guerra poveri': 1669,
#  'perch salvini': 2707,
#  'poa poa': 2781,
#  'regno unito': 3149,
#  'ormai cato': 2447,
#  'fatevene ragione': 1385,
#  'popolo popolo': 2849,
#  'consigliere leghista': 880,
#  'agenti polizia': 48,
#  'polizia locale': 2830,
#  'italia europa': 1787,
#  'sindaco leghista': 3613,
#  'tante cose': 3819,
#  'scelte politiche': 3463,
#  'destra italiana': 1059,
#  'padri costituenti': 2471,
#  'azza giovanni': 300,
#  'pubblicato foto': 3042,
#  'italia sinistra': 1823,
#  'presidente camera': 2926,
#  'orgoglio italiano': 2445,
#  'viva italia': 4108,
#  'inno mameli': 1736,
#  'gilet gialli': 1547,
#  'ferro fuoco': 1404,
#  'frode fiscale': 1506,
#  'richiedente asilo': 3205,
#  'sar giornata': 3430,
#  'san etro': 3394,
#  'mario monti': 2131,
#  'bisogno aiuto': 403,
#  'bambino italiani': 329,
#  'italiani poveri': 1858,
#  'libro paga': 2004,
#  'cambiato idea': 546,
#  'mettendo rischio': 2189,
#  'tasso disoccupazione': 3841,
#  'saluto romano': 3323,
#  'prossimo sar': 3031,
#  'voto italiani': 4187,
#  'pagamenti elettronici': 2479,
#  'razzista fascista': 3121,
#  'raggiunto accordo': 3113,
#  'tassa plastica': 3834,
#  'leggere commenti': 1967,
#  'oscar wilde': 2449,
#  'alto livello': 87,
#  'cose belle': 937,
#  'vogliamo parlare': 4120,
#  'lica lica': 2006,
#  'storia triste': 3767,
#  'azza sardine': 314,
#  'on intellettuale': 2422,
#  'lega fratelli': 1928,
#  'fratelli italia': 1501,
#  'bella figura': 360,
#  'diritti umani': 1125,
#  'francesca mannocchi': 1491,
#  'dicono cose': 1088,
#  'lica buongiorno': 2005,
#  'green economy': 1641,
#  'movimento politico': 2280,
#  'vecchia politica': 3990,
#  'brutta persona': 442,
#  'dicembre azza': 1080,
#  'odio violenza': 2413,
#  'aicolo costituzione': 55,
#  'rendi conto': 3158,
#  'perch vorrei': 2731,
#  'vorrei ricordare': 4148,
#  'cose vanno': 948,
#  'minacce moe': 2242,
#  'salvini pensa': 3367,
#  'resa conto': 3186,
#  'vuoi sapere': 4203,
#  'albero natale': 62,
#  'accordo italia': 16,
#  'francia germania': 1492,
#  'buone notizie': 495,
#  'domenica novembre': 1176,
#  'letto tweet': 1986,
#  'perch tanti': 2716,
#  'ama prossimo': 95,
#  'azza pulita': 309,
#  'buona serata': 488,
#  'dieci minuti': 1090,
#  'casco perch': 628,
#  'perch vero': 2723,
#  'bella storia': 371,
#  'minuto silenzio': 2253,
#  'italia intera': 1796,
#  'caro salvini': 615,
#  'vincere facile': 4085,
#  'fondi europei': 1464,
#  'moi mare': 2264,
#  'viene voglia': 4076,
#  'account twitter': 24,
#  'vittorio feltri': 4106,
#  'sento parlare': 3558,
#  'cittadinanza onoraria': 759,
#  'paura perch': 2580,
#  'paura paura': 2579,
#  'tanti auguri': 3823,
#  'silvia romano': 3603,
#  'rom lazio': 3273,
#  'rendersi conto': 3156,
#  'esattamente contrario': 1275,
#  'sesto san': 3577,
#  'italia salvini': 1821,
#  'sentenza cucchi': 3550,
#  'avviso naviganti': 290,
#  'diretta fb': 1109,
#  'bella idea': 363,
#  'sinistra italia': 3622,
#  'salv ni': 3324,
#  'sar azza': 3423,
#  'azza perch': 306,
#  'diritti civili': 1121,
#  'rendiamo conto': 3159,
#  'domenica prossima': 1178,
#  'dargli too': 1000,
#  'acqua alta': 30,
#  'decreti salvini': 1025,
#  'unica vera': 3960,
#  'rendo conto': 3160,
#  'destra sinistra': 1063,
#  'buona notte': 483,
#  'azza maggiore': 301,
#  'italia migliore': 1804,
#  'steve bannon': 3755,
#  'vecchi paiti': 3989,
#  'salvini risponde': 3376,
#  'rispondere domande': 3251,
#  'lega stelle': 1944,
#  'antoni soli': 172,
#  'soli spencer': 3676,
#  'pecora elettrica': 2620,
#  'raccolta fondi': 3098,
#  'buona giornata': 478,
#  'san francesco': 3395,
#  'vicesindaco leghista': 4057,
#  'continuate votare': 910,
#  'votare salvini': 4165,
#  'domenica mattina': 1175,
#  'moto acqua': 2277,
#  'vuoi mettere': 4202,
#  'buongiorno buona': 499,
#  'perch bisogna': 2644,
#  'assolutamente accordo': 243,
#  'salvini giorgia': 3352,
#  'bella notizia': 368,
#  'buon pomeriggio': 461,
#  'domani mattina': 1168,
#  'cori razzisti': 929,
#  'istituzione commissione': 1769,
#  'testa testa': 3865,
#  'azzale loreto': 317,
#  'razzisti fascisti': 3122,
#  'lingua italiana': 2012,
#  'bisogna care': 398,
#  'perch paura': 2691,
#  'vigile fuoco': 4077,
#  'manina salvini': 2101,
#  'cani gatti': 572,
#  'operaio ilva': 2434,
#  'chiusura ilva': 739,
#  'capo ultr': 585,
#  'ano ano': 159,
#  'accordi libia': 15,
#  'aspetto domani': 234,
#  'buona pace': 484,
#  'poche cose': 2786,
#  'padre madre': 2469,
#  'ragione perch': 3114,
#  'enamente ragione': 1259,
#  'muro berlino': 2288,
#  'leggi razziali': 1974,
#  'difendere diritti': 1093,
#  'ezio mauro': 1324,
#  'centro destra': 687,
#  'destra estrema': 1058,
#  'marcia rom': 2114,
#  'vogliamo sapere': 4121,
#  'carfagna italia': 603,
#  'estrema destra': 1284,
#  'voto contrario': 4184,
#  'istituire commissione': 1768,
#  'buon mercoled': 458,
#  'scorsa settimana': 3490,
#  'odiatori seriali': 2406,
#  'candidato sindaco': 571,
#  'prossima settimana': 3025,
#  'perch fate': 2670,
#  'tanta voglia': 3817,
#  'fascismo nazismo': 1369,
#  'testa cuore': 3864,
#  'appena finito': 182,
#  'sinistra perch': 3625,
#  'cittadino comune': 771,
#  'gentile signora': 1529,
#  'sabato mattina': 3305,
#  'rom napoli': 3275,
#  'elettori lega': 1233,
#  'europa italia': 1305,
#  'politiche sociali': 2820,
#  'italiani stranieri': 1861,
#  'renzi calenda': 3163,
#  'oriana fallaci': 2446,
#  'perch possiamo': 2700,
#  'vero amore': 4042,
#  'tantissimi auguri': 3829,
#  'destra destra': 1057,
#  'buongiorno bella': 497,
#  'bella foto': 361,
#  'bambina bibbiano': 326,
#  'seri problemi': 3565,
#  'sogni oro': 3656,
#  'buon motivo': 459,
#  'amici twitter': 103,
#  'paito italia': 2504,
#  'viene mente': 4073,
#  'perch voleva': 2729,
#  'impegni presi': 1709,
#  'popolo curdo': 2847,
#  'frega cazzo': 1504,
#  'buon luned': 456,
#  'buongiorno buongiorno': 500,
#  'perch vergogna': 2722,
#  'perch dovrei': 2666,
#  'scale mobili': 3457,
#  'italiani votano': 1864,
#  'azioni concrete': 294,
#  'almeno moi': 79,
#  'soldi spesi': 3671,
#  'premio nobel': 2895,
#  'nobel pace': 2350,
#  'prendono culo': 2915,
#  'social network': 3650,
#  'bella italia': 366,
#  'patrimonio umanit': 2574,
#  'elezioni marzo': 1241,
#  'buttare soldi': 511,
#  'rom ottobre': 3276,
#  'raccolta rifiuti': 3099,
#  'rifiuti rom': 3220,
#  'beni culturali': 380,
#  'riesco smettere': 3217,
#  'odio rabbia': 2407,
#  'tribunale minori': 3916,
#  'paesi europei': 2475,
#  'cose serie': 947,
#  'volevo chiedere': 4143,
#  'facolt rispondere': 1337,
#  'tasche italiani': 3832,
#  'realizzate foglio': 3129,
#  'risponde domande': 3250,
#  'vero salvini': 4048,
#  'perch viene': 2724,
#  'donne bambino': 1189,
#  'buonanotte amici': 492,
#  'persona seria': 2764,
#  'cose possono': 946,
#  'prendendo giro': 2903,
#  'salvini vuole': 3388,
#  'sabato domenica': 3304,
#  'sindaco riace': 3617,
#  'giusto ricordare': 1602,
#  'cose buone': 938,
#  'vergogna vergogna': 4035,
#  'pepno impastato': 2637,
#  'colonna sonora': 814,
#  'voti salvini': 4180,
#  'andato onda': 145,
#  'mare rom': 2119,
#  'voglio andare': 4124,
#  'grandi citt': 1632,
#  'buon sabato': 465,
#  'poveri cristi': 2886,
#  'quei bambino': 3073,
#  'voglio ringraziare': 4126,
#  'coraggio andare': 924,
#  'andare vedere': 135,
#  'militari italiani': 2239,
#  'porca miseria': 2853,
#  ...}

# %% [markdown]
# # NAIVE BAYESIAN CLASSIFIER

# %%
# Fit the training dataset on the NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)
# Predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_Y)*100)
# Out:
# Naive Bayes Accuracy Score ->  79.31818181818183

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(predictions_NB, Test_Y))
# Out:
# [[200  59]
#  [ 32 149]]

# %% [markdown]
# # Confusion matrix

# %%
from mlxtend.plotting import plot_confusion_matrix

# %%
import matplotlib.pyplot as plt
multiclass = np.array([[200, 59, ],
                       [32, 149]])


fig, ax = plot_confusion_matrix(conf_mat=multiclass,
                                colorbar=False,
                                show_absolute=True,
                                show_normed=True
                                )
plt.title('Naive Bayes Bigrams 100%')
plt.show()

# %% [markdown]
# # SUPPORT VECTOR MACHINE

# %%
#grid search
import numpy as np
from sklearn.model_selection import GridSearchCV
grid={"C":[0,0.5,1,1.5], "kernel":["linear","poly","sigmoid"],"gamma":['scale','auto']}
SVM=svm.SVC()
SVM_cv=GridSearchCV(SVM,grid,cv=10)
SVM_cv.fit(Train_X_Tfidf,Train_Y)

# %%
print("tuned hpyerparameters :(best parameters) ", SVM_cv.best_params_)
print("accuracy :",SVM_cv.best_score_)

# %%
# Classifier - Algorithm - SVM
# Fit the training dataset on the classifier
SVM = svm.SVC(C=0.5, kernel='linear', gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)
# Predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  83.18181818181817

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(predictions_SVM, Test_Y))
# Out:
# [[202  44]
#  [ 30 164]]

# %%
multiclass = np.array([[202, 44, ],
                       [30, 164,]])


fig, ax = plot_confusion_matrix(conf_mat=multiclass,
                                colorbar=False,
                                show_absolute=True,
                                show_normed=True
                                )
plt.title('SVM bigrams 100%')
plt.show()
